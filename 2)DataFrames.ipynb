# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #### Creating a DataFrame

# %%
data = {
    'Name': ['John', 'Anna', 'Peter', 'Linda'],
    'Age': [28, 34, 29, 42],
    'City': ['New York', 'Paris', 'Berlin', 'London'],
    'Salary': [65000, 70000, 62000, 85000]
}
df = pd.DataFrame(data)

# %%
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
data_list = [
    ['John', 28, 'New York', 65000],
    ['Anna', 34, 'Paris', 70000],
    ['Peter', 29, 'Berlin', 62000],
    ['Linda', 42, 'London', 85000]
]
df2 = pd.DataFrame(data_list)
col = ["Name", "Age", "City", "Salary"]
df2 = pd.DataFrame(data_list, columns=col)

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %% [markdown]
# #### Selection and indexing of Columns

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2["Name"]
# Out:
# 0     John
# 1     Anna
# 2    Peter
# 3    Linda
# Name: Name, dtype: object

# %%
# if I want to choose multiple column then 
df2[["Name", "Salary"]]
# Out:
#     Name  Salary
# 0   John   65000
# 1   Anna   70000
# 2  Peter   62000
# 3  Linda   85000

# %% [markdown]
# #### Creating a new column

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2["Gender"] = ["Male", "Female", "Male", "Female"]

# %%
df2
# Out:
#     Name  Age      City  Salary  Gender
# 0   John   28  New York   65000    Male
# 1   Anna   34     Paris   70000  Female
# 2  Peter   29    Berlin   62000    Male
# 3  Linda   42    London   85000  Female

# %% [markdown]
# #### Removing Columns

# %%
df2
# Out:
#     Name  Age      City  Salary  Gender
# 0   John   28  New York   65000    Male
# 1   Anna   34     Paris   70000  Female
# 2  Peter   29    Berlin   62000    Male
# 3  Linda   42    London   85000  Female

# %%
df2.drop(["City", "Salary"], axis=1) # inplace = True is for permanently delete
# Out:
#     Name  Age  Gender
# 0   John   28    Male
# 1   Anna   34  Female
# 2  Peter   29    Male
# 3  Linda   42  Female

# %%
df2
# Out:
#     Name  Age      City  Salary  Gender
# 0   John   28  New York   65000    Male
# 1   Anna   34     Paris   70000  Female
# 2  Peter   29    Berlin   62000    Male
# 3  Linda   42    London   85000  Female

# %%
# now If I want to delete a row then

# %%
df2.drop(0, axis=0)
# Out:
#     Name  Age    City  Salary  Gender
# 1   Anna   34   Paris   70000  Female
# 2  Peter   29  Berlin   62000    Male
# 3  Linda   42  London   85000  Female

# %% [markdown]
# #### Selecting Rows

# %%
df2
# Out:
#     Name  Age      City  Salary  Gender
# 0   John   28  New York   65000    Male
# 1   Anna   34     Paris   70000  Female
# 2  Peter   29    Berlin   62000    Male
# 3  Linda   42    London   85000  Female

# %%
# loc is use for selecting rows in panda
df2.loc[0]
# Out:
# Name          John
# Age             28
# City      New York
# Salary       65000
# Gender        Male
# Name: 0, dtype: object

# %%
# for selecting multiple rows in pandas
df2.loc[[0,3]]
# Out:
#     Name  Age      City  Salary  Gender
# 0   John   28  New York   65000    Male
# 3  Linda   42    London   85000  Female

# %% [markdown]
# #### Selecting Subsets of Rows and Columns

# %%
df2
# Out:
#     Name  Age      City  Salary  Gender
# 0   John   28  New York   65000    Male
# 1   Anna   34     Paris   70000  Female
# 2  Peter   29    Berlin   62000    Male
# 3  Linda   42    London   85000  Female

# %%
# suppose we need to select only label 1,2 inside data Name and Salary only
df2.loc[[1,2]][["Name", "Salary"]]
# Out:
#     Name  Salary
# 1   Anna   70000
# 2  Peter   62000

# %% [markdown]
# #### Conditional Selection

# %%
df2
# Out:
#     Name  Age      City  Salary  Gender
# 0   John   28  New York   65000    Male
# 1   Anna   34     Paris   70000  Female
# 2  Peter   29    Berlin   62000    Male
# 3  Linda   42    London   85000  Female

# %%
# I only want to see those people who are above only 30 age
df2[df2["Age"] > 30]
# Out:
#     Name  Age    City  Salary  Gender
# 1   Anna   34   Paris   70000  Female
# 3  Linda   42  London   85000  Female

# %%
# I only want to see those people who are above only 30 age and city = paris
df2[(df2["Age"] > 30) & (df2['City'] == "Paris")]
# Out:
#    Name  Age   City  Salary  Gender
# 1  Anna   34  Paris   70000  Female
